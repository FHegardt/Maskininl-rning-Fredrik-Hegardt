# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../Advertising.csv", index_col = 0)
index_col = 0
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.describe().T
# Out:
#             count      mean        std  min     25%     50%      75%    max
# Unnamed: 0  200.0  100.5000  57.879185  1.0  50.750  100.50  150.250  200.0
# TV          200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio       200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper   200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales       200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 3), dpi=100)

for i, feature in enumerate(df.columns[:-1]):
    sns.scatterplot(data = df, x = feature, y = "sales", ax = ax[i])
    ax[i].set(xlabel = "Spending", title = f"{feature} spendings")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\fredr\OneDrive\Documents\GitHub\Maskininl-rning-Fredrik-Hegardt\Code-Along\L0_Linear_Regression.ipynb Cell 3' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/fredr/OneDrive/Documents/GitHub/Maskininl-rning-Fredrik-Hegardt/Code-Along/L0_Linear_Regression.ipynb#ch0000002?line=0'>1</a> fig, ax = plt.subplots(1, 3, figsize=(12, 3), dpi=100)
#       <a href='vscode-notebook-cell:/c%3A/Users/fredr/OneDrive/Documents/GitHub/Maskininl-rning-Fredrik-Hegardt/Code-Along/L0_Linear_Regression.ipynb#ch0000002?line=2'>3</a> for i, feature in enumerate(df.columns[:-1]):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/fredr/OneDrive/Documents/GitHub/Maskininl-rning-Fredrik-Hegardt/Code-Along/L0_Linear_Regression.ipynb#ch0000002?line=3'>4</a>     sns.scatterplot(data = df, x = feature, y = "sales", ax = ax[i])
#       <a href='vscode-notebook-cell:/c%3A/Users/fredr/OneDrive/Documents/GitHub/Maskininl-rning-Fredrik-Hegardt/Code-Along/L0_Linear_Regression.ipynb#ch0000002?line=4'>5</a>     ax[i].set(xlabel = "Spending", title = f"{feature} spendings")
#
# IndexError: index 3 is out of bounds for axis 0 with size 3
