# %%
#0 Iris flower dataset
#b)
from sklearn import datasets
import pandas as pd
import seaborn as sns

df = datasets.load_iris(as_frame = True)
df = df.frame
df.head(15)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# 5                 5.4               3.9                1.7               0.4
# 6                 4.6               3.4                1.4               0.3
# 7                 5.0               3.4                1.5               0.2
# 8                 4.4               2.9                1.4               0.2
# 9                 4.9               3.1                1.5               0.1
# 10                5.4               3.7                1.5               0.2
# ...

# %%
sns.scatterplot(data = df, x ="petal width (cm)", y ="petal length (cm)", hue="target")
# Out:
# <AxesSubplot:xlabel='petal width (cm)', ylabel='petal length (cm)'>
